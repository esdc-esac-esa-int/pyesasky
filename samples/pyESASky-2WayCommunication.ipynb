# %% [markdown]
# # Examples of getting data back from ESASky into the notebook

# %%
from pyesasky import ESASkyWidget
import pandas as pd

# %%
esasky = ESASkyWidget()

# %%
esasky
# Out:
# ESASkyWidget(layout=Layout(align_self='stretch', height='400px'))

# %% [markdown]
# ## Gets the center of the current view.

# %% [markdown]
# Possible parameters are "J2000" and "GALACTIC". Default is J2000

# %%
coorGal=esasky.getCenter('GALACTIC')
coorJ2000=esasky.getCenter('J2000')
coorDefault=esasky.getCenter()

print(coorJ2000)
print("Ra in J2000: " + str(coorJ2000['ra']))
print("Ra in GALACTIC: " + str(coorGal['ra']))
print("Default is J2000 Ra: " + str(coorDefault['ra']))
# Out:
# {'ra': 13.104583333333332, 'dec': 56.565, 'fov': 0.99898474588}
# Ra in J2000: 13.104583333333332
# Ra in GALACTIC: 123.06779157416017
# Default is J2000 Ra: 13.104583333333332

# %% [markdown]
# ### Timeout can be manually set for how long to wait for a response

# %%
esasky.messageTimeOut=20 #In seconds

# %% [markdown]
# ## Get the counts of observation, catalogues, spectra and publications in the current view

# %%
esasky.goToRADec('15 24 10', '-57 45 35')
count=esasky.getCataloguesCount()
print(count)
# Out:
# {'AllWise': 20302, '2MASS': 84183, 'INTEGRAL': 0, 'CHANDRA': 0, 'XMM-EPIC-STACK': 0, 'XMM-EPIC': 5, 'XMM-OM': 0, 'XMM-SLEW': 0, 'Tycho-2': 93, 'Gaia DR2': 1602114, 'Hipparcos-2': 0, 'HSC': 3277, 'Herschel-HPPSC-070': 93, 'Herschel-HPPSC-100': 0, 'Herschel-HPPSC-160': 254, 'Herschel-SPSC-250': 0, 'Herschel-SPSC-350': 0, 'Herschel-SPSC-500': 0, 'Planck-PGCC': 2, 'Planck-PCCS2E-HFI': 35, 'Planck-PCCS2-HFI': 0, 'Planck-PCCS2-LFI': 0, 'Planck-PSZ2': 0, 'Total': 1710358}

# %%
esasky.getObservationsCount()
# Out:
# {'INTEGRAL': 0,
#  'XMM': 0,
#  'Chandra': 0,
#  'SUZAKU': 0,
#  'XMM-OM-OPTICAL': 0,
#  'XMM-OM-UV': 0,
#  'HST': 0,
#  'Herschel': 0,
#  'ISO': 0,
#  'Total': 0}

# %%
esasky.getSpectraCount()
# Out:
# {'XMM-NEWTON': 0,
#  'Chandra': 0,
#  'IUE': 0,
#  'HST(UV)': 0,
#  'HST(OPTICAL)': 0,
#  'HST(IR)': 0,
#  'ISO(IR)': 0,
#  'Herschel': 0,
#  'Total': 0}

# %%
esasky.getPublicationsCount()
# Out:
# {'ADS PUB': 363, 'Total': 363}

# %% [markdown]
# ## Plot footprints from selected mission

# %% [markdown]
# Availabe missionIds can be seen in the various get..Count commands

# %%
esasky.goToTargetName('M51')

# %%
esasky.plotObservations('HST')
# Out:
# Image observations from missionId: HST displayed in the ESASky

# %% [markdown]
# ## Get all the metadata of the plotted footprints from the current active panel

# %%
data=esasky.getResultPanelData()

# %% [markdown]
# Use for example pandas for structuring the data

# %%
pd.DataFrame.from_dict(data).transpose()
# Out:
#     collection              dec_deg exposure_duration  \
# 0          HST  47.1789180964924881           255.752
# 1          HST  47.2288940072132633             500.0
# 2          HLA   47.192020504132131            1400.0
# 3          HLA   47.176779417882301             480.0
# 4          HST  47.2299524741745387               0.5
# 5          HST  47.1741999299834944             400.0
# 6          HST   47.186391925582285            2200.0
# 7          HST  47.2288940072132633             500.0
# 8          HLA   47.169719034697863            1072.0
# 9          HST  47.1956675344536194             192.0
# 10         HST  47.2070807706845699             128.0
# 11         HST  47.2070807706845699             128.0
# 12         HLA  47.2076958273823664            1428.0
# 13         HLA  47.2198633384389339               1.0
# 14         HLA  47.1788101445482013         767.43567
# 15         HST  47.1850059203716725             500.0
# 16         HST  47.2017950050797381             128.0
# 17         HST  47.1920440061082545             700.0
# 18         HST   47.160761132200129             680.0
# 19         HST  47.1767679019137987         29205.066
# 20         HLA  47.1923511320557481            1200.0
# 21         HST  47.2128208802168885             680.0
# 22         HLA  47.1767709768568722            3600.0
# 23         HST  47.1868670869884497            2200.0
# 24         HLA  47.1902221713479264         1811.7441
# 25         HLA  47.2195618761712907         2011.7458
# 26         HLA  47.2150358209028198             340.0
# 27         HLA  47.1552966488039402         2011.7458
# 28         HST  47.1954140415279824             128.0
# 29         HLA  47.1607651233452358            2040.0
# ..         ...                  ...               ...
# 878        HLA  47.1607651233452358             680.0
# 879        HLA  47.1697469994398944            1784.0
# 880        HLA  47.1956945599658795         191.87488
# 881        HLA  47.1608959396714624             680.0
# 882        HST  47.2436922908371102            2882.0
# 883        HLA  47.2289647665744923             500.0
# 884        HLA  47.1786526147192689         767.43567
# 885        HLA  47.1868095974792467         2623.4873
# 886        HLA  47.2472710360929753            1520.0
# 887        HST  47.1864051536446496            2200.0
# 888        HLA  47.1767779632858151            1680.0
# 889        HLA  47.1879025453973071         611.74146
# 890        HST  47.1696997670112239            1232.0
# 891        HST  47.1777971579269177         26680.941
# 892        HST  47.1868794635963411            2200.0
# 893        HST  47.2288940072132633             500.0
# 894        HST  47.1879523324310668            5400.0
# 895        HLA  47.1714237168329902            2600.0
# 896        HST  47.2230216648829071            5400.0
# 897        HST  47.1585388839068855             680.0
# 898        HST  47.2288940072132633             500.0
# 899        HST  47.1864423911690452            2200.0
# 900        HLA  47.1773291722141579            1860.0
# 901        HST   47.173911150137684             400.0
# 902        HLA  47.1608002881957233             340.0
# 903        HST  47.1585741322796039             680.0
# 904        HST  47.1870696945622896             384.0
# 905        HLA  47.1749839938441013            1600.0
# 906        HLA   47.153299258202594            2600.0
# 907        HLA  47.1767853064776972             960.0
#
#                       filter instrument_name                observation_id  \
# 0                      F110W     NICMOS/NIC3                     n90zq5020
# 1                      F814W        WFPC2/PC                     u6eh040cr
# 2                      F439W           WFPC2   hst_05777_02_wfpc2_total_wf
# 3                      F250W             ACS    hst_10182_p3_acs_hrc_f250w
# 4                      F336W       WFPC2/WFC                     u9ga0301m
# 5                      F606W        WFPC2/PC                     ua2p1701m
# 6                      F606W         ACS/WFC                     jd8f23010
# 7                      F814W        WFPC2/PC                     u6eh040ar
# 8                      F435W             ACS    hst_13433_02_acs_wfc_f435w
# 9                      F190N     NICMOS/NIC2                     n48r01070
# 10                     F110W     NICMOS/NIC3                     n48r02060
# 11                     F160W     NICMOS/NIC3                     n48r02070
# 12                     F435W             ACS    hst_10182_pe_acs_wfc_total
# 13                     F336W           WFPC2   hst_10501_03_wfpc2_total_wf
# 14               F110W/F160W          NICMOS   hst_10182_q3_nic_nic3_total
# 15                     F814W        WFPC2/PC                     u6eh030ar
# 16                     F110W     NICMOS/NIC3                     n48r020b0
# 17                     F814W       WFPC2/WFC                     u50q0103r
# 18                     F435W         ACS/WFC                     j97c51r3q
# 19                     F220W         ACS/HRC                     j90zpd030
# 20                     F336W           WFPC2   hst_05652_02_wfpc2_f336w_pc
# 21                     F435W         ACS/WFC                     j97c43n2q
# 22                     F220W             ACS    hst_10182_pd_acs_hrc_f220w
# 23                     F814W         ACS/WFC                     jd8f15020
# 24                     F128N            WFC3    hst_12490_18_wfc3_ir_f128n
# 25                     F128N            WFC3    hst_12490_03_wfc3_ir_f128n
# 26                     F814W             ACS    hst_10452_33_acs_wfc_f814w
# 27                     F128N            WFC3    hst_12490_04_wfc3_ir_f128n
# 28                     F160W     NICMOS/NIC3                     n48r020m0
# 29   F435W/F814W/F658N/F555W             ACS    hst_10452_51_acs_wfc_total
# ..                       ...             ...                           ...
# 878                    F435W             ACS    hst_10452_51_acs_wfc_f435w
# 879                    F336W            WFC3  hst_13433_01_wfc3_uvis_f336w
# 880                    F187N          NICMOS    hst_7237_01_nic_nic2_f187n
# 881                    F435W             ACS    hst_10452_54_acs_wfc_f435w
# 882                    F275W       WFC3/UVIS                     icmx06040
# 883                    F218W           WFPC2   hst_08816_t6_wfpc2_f218w_pc
# 884              F110W/F160W          NICMOS   hst_10182_q1_nic_nic3_total
# 885              F128N/F110W            WFC3    hst_12490_02_wfc3_ir_total
# 886                    F435W             ACS    hst_13364_0h_acs_wfc_f435w
# 887                    F606W         ACS/WFC                     jd8f25010
# 888        F220W/F330W/F250W             ACS    hst_10182_p4_acs_hrc_total
# 889                    F110W            WFC3    hst_12490_05_wfc3_ir_f110w
# 890                    F555W         ACS/WFC                     jc7s02020
# 891                   PR200L         ACS/HRC                     j90zp1060
# 892                    F606W         ACS/WFC                     jd8f34010
# 893                    F555W        WFPC2/PC                     u6eh0401r
# 894                    F673N       WFC3/UVIS                     ibvx02010
# 895                    F336W           WFPC2   hst_10501_05_wfpc2_f336w_wf
# 896                    F673N       WFC3/UVIS                     ibvx01010
# 897                    F435W         ACS/WFC                     j97c61h9q
# 898                    F450W        WFPC2/PC                     u6eh0405r
# 899                    F606W         ACS/WFC                     jd8f27010
# 900                   PR200L             ACS   hst_10182_p8_acs_hrc_pr200l
# 901                    F814W        WFPC2/PC                     ua2p1707m
# 902                    F814W             ACS    hst_10452_52_acs_wfc_f814w
# 903                    F435W         ACS/WFC                     j97c62xzq
# 904                    F215N     NICMOS/NIC3                     n48r021d0
# 905                    F814W           WFPC2   hst_11229_25_wfpc2_f814w_pc
# 906                    F336W           WFPC2   hst_10501_06_wfpc2_f336w_wf
# 907                    F220W             ACS    hst_10182_p6_acs_hrc_f220w
#
#                                           postcard_url  \
# 0    http://archives.esac.esa.int/ehst-sl-server/se...
# 1    http://archives.esac.esa.int/ehst-sl-server/se...
# 2    http://archives.esac.esa.int/ehst-sl-server/se...
# 3    http://archives.esac.esa.int/ehst-sl-server/se...
# 4    http://archives.esac.esa.int/ehst-sl-server/se...
# 5    http://archives.esac.esa.int/ehst-sl-server/se...
# 6    http://archives.esac.esa.int/ehst-sl-server/se...
# 7    http://archives.esac.esa.int/ehst-sl-server/se...
# 8    http://archives.esac.esa.int/ehst-sl-server/se...
# 9    http://archives.esac.esa.int/ehst-sl-server/se...
# 10   http://archives.esac.esa.int/ehst-sl-server/se...
# 11   http://archives.esac.esa.int/ehst-sl-server/se...
# 12   http://archives.esac.esa.int/ehst-sl-server/se...
# 13   http://archives.esac.esa.int/ehst-sl-server/se...
# 14   http://archives.esac.esa.int/ehst-sl-server/se...
# 15   http://archives.esac.esa.int/ehst-sl-server/se...
# 16   http://archives.esac.esa.int/ehst-sl-server/se...
# 17   http://archives.esac.esa.int/ehst-sl-server/se...
# 18   http://archives.esac.esa.int/ehst-sl-server/se...
# 19   http://archives.esac.esa.int/ehst-sl-server/se...
# 20   http://archives.esac.esa.int/ehst-sl-server/se...
# 21   http://archives.esac.esa.int/ehst-sl-server/se...
# 22   http://archives.esac.esa.int/ehst-sl-server/se...
# 23   http://archives.esac.esa.int/ehst-sl-server/se...
# 24   http://archives.esac.esa.int/ehst-sl-server/se...
# 25   http://archives.esac.esa.int/ehst-sl-server/se...
# 26   http://archives.esac.esa.int/ehst-sl-server/se...
# 27   http://archives.esac.esa.int/ehst-sl-server/se...
# 28   http://archives.esac.esa.int/ehst-sl-server/se...
# 29   http://archives.esac.esa.int/ehst-sl-server/se...
# ..                                                 ...
# 878  http://archives.esac.esa.int/ehst-sl-server/se...
# 879  http://archives.esac.esa.int/ehst-sl-server/se...
# 880  http://archives.esac.esa.int/ehst-sl-server/se...
# 881  http://archives.esac.esa.int/ehst-sl-server/se...
# 882  http://archives.esac.esa.int/ehst-sl-server/se...
# 883  http://archives.esac.esa.int/ehst-sl-server/se...
# 884  http://archives.esac.esa.int/ehst-sl-server/se...
# 885  http://archives.esac.esa.int/ehst-sl-server/se...
# 886  http://archives.esac.esa.int/ehst-sl-server/se...
# 887  http://archives.esac.esa.int/ehst-sl-server/se...
# 888  http://archives.esac.esa.int/ehst-sl-server/se...
# 889  http://archives.esac.esa.int/ehst-sl-server/se...
# 890  http://archives.esac.esa.int/ehst-sl-server/se...
# 891  http://archives.esac.esa.int/ehst-sl-server/se...
# 892  http://archives.esac.esa.int/ehst-sl-server/se...
# 893  http://archives.esac.esa.int/ehst-sl-server/se...
# 894  http://archives.esac.esa.int/ehst-sl-server/se...
# 895  http://archives.esac.esa.int/ehst-sl-server/se...
# 896  http://archives.esac.esa.int/ehst-sl-server/se...
# 897  http://archives.esac.esa.int/ehst-sl-server/se...
# 898  http://archives.esac.esa.int/ehst-sl-server/se...
# 899  http://archives.esac.esa.int/ehst-sl-server/se...
# 900  http://archives.esac.esa.int/ehst-sl-server/se...
# 901  http://archives.esac.esa.int/ehst-sl-server/se...
# 902  http://archives.esac.esa.int/ehst-sl-server/se...
# 903  http://archives.esac.esa.int/ehst-sl-server/se...
# 904  http://archives.esac.esa.int/ehst-sl-server/se...
# 905  http://archives.esac.esa.int/ehst-sl-server/se...
# 906  http://archives.esac.esa.int/ehst-sl-server/se...
# 907  http://archives.esac.esa.int/ehst-sl-server/se...
#
#                                            product_url               ra_deg  \
# 0    http://archives.esac.esa.int/ehst-sl-server/se...  202.472096224119952
# 1    http://archives.esac.esa.int/ehst-sl-server/se...  202.504186374366839
# 2    http://archives.esac.esa.int/ehst-sl-server/se...  202.486694129643922
# 3    http://archives.esac.esa.int/ehst-sl-server/se...  202.470212102569576
# 4    http://archives.esac.esa.int/ehst-sl-server/se...  202.480479503538533
# 5    http://archives.esac.esa.int/ehst-sl-server/se...  202.472513051493848
# 6    http://archives.esac.esa.int/ehst-sl-server/se...   202.49590663881753
# 7    http://archives.esac.esa.int/ehst-sl-server/se...  202.504186374366839
# 8    http://archives.esac.esa.int/ehst-sl-server/se...   202.52117175124809
# 9    http://archives.esac.esa.int/ehst-sl-server/se...  202.469272998951652
# 10   http://archives.esac.esa.int/ehst-sl-server/se...   202.46117816645409
# 11   http://archives.esac.esa.int/ehst-sl-server/se...   202.46117816645409
# 12   http://archives.esac.esa.int/ehst-sl-server/se...   202.55143212626254
# 13   http://archives.esac.esa.int/ehst-sl-server/se...   202.47290175607057
# 14   http://archives.esac.esa.int/ehst-sl-server/se...  202.472443335574752
# 15   http://archives.esac.esa.int/ehst-sl-server/se...  202.532104606344205
# 16   http://archives.esac.esa.int/ehst-sl-server/se...  202.444901367142137
# 17   http://archives.esac.esa.int/ehst-sl-server/se...  202.455113156010981
# 18   http://archives.esac.esa.int/ehst-sl-server/se...  202.504328338357169
# 19   http://archives.esac.esa.int/ehst-sl-server/se...  202.470192348901918
# 20   http://archives.esac.esa.int/ehst-sl-server/se...  202.475322181734157
# 21   http://archives.esac.esa.int/ehst-sl-server/se...  202.427710961438038
# 22   http://archives.esac.esa.int/ehst-sl-server/se...  202.470186390604368
# 23   http://archives.esac.esa.int/ehst-sl-server/se...  202.495136250617463
# 24   http://archives.esac.esa.int/ehst-sl-server/se...  202.509786314192439
# 25   http://archives.esac.esa.int/ehst-sl-server/se...  202.436680971654226
# 26   http://archives.esac.esa.int/ehst-sl-server/se...  202.508304242153571
# 27   http://archives.esac.esa.int/ehst-sl-server/se...  202.457224852011478
# 28   http://archives.esac.esa.int/ehst-sl-server/se...  202.469511560916146
# 29   http://archives.esac.esa.int/ehst-sl-server/se...  202.504338411132238
# ..                                                 ...                  ...
# 878  http://archives.esac.esa.int/ehst-sl-server/se...  202.504338411132238
# 879  http://archives.esac.esa.int/ehst-sl-server/se...   202.52221514095632
# 880  http://archives.esac.esa.int/ehst-sl-server/se...  202.469218070867527
# 881  http://archives.esac.esa.int/ehst-sl-server/se...  202.505586154269821
# 882  http://archives.esac.esa.int/ehst-sl-server/se...  202.481940864207303
# 883  http://archives.esac.esa.int/ehst-sl-server/se...  202.504112750018407
# 884  http://archives.esac.esa.int/ehst-sl-server/se...  202.472774382742699
# 885  http://archives.esac.esa.int/ehst-sl-server/se...  202.424549463473852
# 886  http://archives.esac.esa.int/ehst-sl-server/se...  202.357387027221165
# 887  http://archives.esac.esa.int/ehst-sl-server/se...  202.496006393696348
# 888  http://archives.esac.esa.int/ehst-sl-server/se...  202.470205935757775
# 889  http://archives.esac.esa.int/ehst-sl-server/se...  202.470140159385295
# 890  http://archives.esac.esa.int/ehst-sl-server/se...  202.521228547338524
# 891  http://archives.esac.esa.int/ehst-sl-server/se...  202.470836049999406
# 892  http://archives.esac.esa.int/ehst-sl-server/se...  202.496520583133076
# 893  http://archives.esac.esa.int/ehst-sl-server/se...  202.504186374366839
# 894  http://archives.esac.esa.int/ehst-sl-server/se...  202.514794232893735
# 895  http://archives.esac.esa.int/ehst-sl-server/se...  202.494570158381919
# 896  http://archives.esac.esa.int/ehst-sl-server/se...  202.483579455852237
# 897  http://archives.esac.esa.int/ehst-sl-server/se...  202.423828214874163
# 898  http://archives.esac.esa.int/ehst-sl-server/se...  202.504186374366839
# 899  http://archives.esac.esa.int/ehst-sl-server/se...  202.496148105067817
# 900  http://archives.esac.esa.int/ehst-sl-server/se...   202.47035754181303
# 901  http://archives.esac.esa.int/ehst-sl-server/se...   202.47259898507599
# 902  http://archives.esac.esa.int/ehst-sl-server/se...  202.504371047048892
# 903  http://archives.esac.esa.int/ehst-sl-server/se...  202.423860838357058
# 904  http://archives.esac.esa.int/ehst-sl-server/se...  202.461139782789274
# 905  http://archives.esac.esa.int/ehst-sl-server/se...  202.472876536876555
# 906  http://archives.esac.esa.int/ehst-sl-server/se...   202.43358773380308
# 907  http://archives.esac.esa.int/ehst-sl-server/se...   202.47020810116868
#
#                 start_time                                              stc_s  \
# 0    2005-07-29 16:01:52.5  POLYGON J2000 202.474500000000006 47.190460999...
# 1    2001-06-09 18:16:52.5  POLYGON J2000 202.496180390000006 47.233541739...
# 2    1995-01-15 16:35:37.5  POLYGON J2000 202.456659999999886 47.181921000...
# 3    2005-07-15 06:56:15.0  POLYGON J2000 202.467194999999975 47.181413000...
# 4    2006-03-31 18:33:45.0  POLYGON J2000 202.469081439999997 47.216363479...
# 5    2007-10-28 20:43:07.5  POLYGON J2000 202.474600629999998 47.167189810...
# 6    2017-06-21 14:03:45.0  POLYGON J2000 202.435618000000005 47.179521999...
# 7    2001-06-09 17:54:22.5  POLYGON J2000 202.496180390000006 47.233541739...
# 8    2014-08-10 03:33:45.0  POLYGON J2000 202.509946999999926 47.175510000...
# 9    1997-09-08 15:05:37.5  POLYGON J2000 202.465129999999988 47.198430999...
# 10   1998-06-28 06:39:22.5  POLYGON J2000 202.466927999999996 47.216876999...
# 11   1998-06-28 06:45:00.0  POLYGON J2000 202.466927999999996 47.216876999...
# 12   2005-08-16 00:05:37.5  POLYGON J2000 202.497963736301415 47.243843108...
# 13   2006-03-31 18:33:45.0  POLYGON J2000 202.442292999999978 47.211473000...
# 14   2005-07-21 11:31:52.5  POLYGON J2000 202.455289999999934 47.179123000...
# 15   2001-06-09 13:07:30.0  POLYGON J2000 202.524125410000011 47.189669629...
# 16   1998-06-28 07:52:30.0  POLYGON J2000 202.450684999999993 47.211604000...
# 17   1999-07-21 06:28:07.5  POLYGON J2000 202.500921419999997 47.188993000...
# 18   2005-01-20 18:39:22.5  POLYGON J2000 202.548094999999989 47.189692000...
# 19   2005-08-15 21:11:15.0  POLYGON J2000 202.474166999999994 47.181758000...
# 20   1994-05-12 09:50:37.5  POLYGON J2000 202.466166999999984 47.189190000...
# 21   2005-01-19 18:39:22.5  POLYGON J2000 202.471520999999996 47.241751999...
# 22   2005-08-15 19:58:07.5  POLYGON J2000 202.464213999999998 47.179808000...
# 23   2017-03-25 16:58:07.5  POLYGON J2000 202.492263000000008 47.228369000...
# 24   2012-09-07 05:43:07.5  POLYGON J2000 202.488387999999958 47.211073000...
# 25   2012-09-01 06:16:52.5  POLYGON J2000 202.415286999999978 47.240223000...
# 26   2005-01-19 23:48:45.0  POLYGON J2000 202.464491649496296 47.244603857...
# 27   2012-09-02 20:31:52.5  POLYGON J2000 202.435840999999982 47.176147999...
# 28   1998-06-28 09:50:37.5  POLYGON J2000 202.475260999999989 47.205210000...
# 29   2005-01-20 18:39:22.5  POLYGON J2000 202.46058085718181 47.1903331794...
# ..                     ...                                                ...
# 878  2005-01-20 18:39:22.5  POLYGON J2000 202.46058085718181 47.1903331794...
# 879  2014-08-07 06:05:37.5  POLYGON J2000 202.509254999999996 47.169002999...
# 880  1997-09-08 15:00:00.0  POLYGON J2000 202.465130999999985 47.198412999...
# 881  2005-01-21 21:50:37.5  POLYGON J2000 202.461818273370284 47.190463991...
# 882  2015-10-28 23:26:15.0  POLYGON J2000 202.473757000000006 47.276358999...
# 883  2001-06-09 17:09:22.5  POLYGON J2000 202.495940999999959 47.234513000...
# 884  2005-07-13 19:41:15.0  POLYGON J2000 202.455800000000039 47.180216000...
# 885  2012-09-01 01:30:00.0  POLYGON J2000 202.40360599999994 47.2077230000...
# 886  2013-09-19 23:26:15.0  POLYGON J2000 202.297741756017558 47.287838889...
# 887  2017-07-02 14:48:45.0  POLYGON J2000 202.437875999999989 47.173557000...
# 888  2005-07-15 10:01:52.5  POLYGON J2000 202.467153999999937 47.181399000...
# 889  2012-09-04 18:56:15.0  POLYGON J2000 202.449196999999998 47.209001000...
# 890  2014-08-10 04:01:52.5  POLYGON J2000 202.512553999999994 47.161220999...
# 891  2005-07-11 07:07:30.0  POLYGON J2000 202.478134000000011 47.180548000...
# 892  2017-09-15 08:37:30.0  POLYGON J2000 202.502526999999986 47.145527999...
# 893  2001-06-09 14:31:52.5  POLYGON J2000 202.496180390000006 47.233541739...
# 894  2012-04-10 11:43:07.5  POLYGON J2000 202.504115000000013 47.155082999...
# 895  2005-11-13 22:18:45.0  POLYGON J2000 202.463536000000005 47.179994999...
# 896  2012-04-09 14:54:22.5  POLYGON J2000 202.472892999999999 47.190151999...
# 897  2005-01-18 18:39:22.5  POLYGON J2000 202.467592999999994 47.187469999...
# 898  2001-06-09 16:07:30.0  POLYGON J2000 202.496180390000006 47.233541739...
# 899  2017-07-19 03:28:07.5  POLYGON J2000 202.443574000000012 47.165252000...
# 900  2005-07-26 06:56:15.0  POLYGON J2000 202.462949911840326 47.182363655...
# 901  2007-10-28 22:46:52.5  POLYGON J2000 202.474686550000001 47.166901029...
# 902  2005-01-21 17:26:15.0  POLYGON J2000 202.460613463972493 47.190368344...
# 903  2005-01-22 21:50:37.5  POLYGON J2000 202.467625999999996 47.187505000...
# 904  1998-06-28 16:07:30.0  POLYGON J2000 202.466925000000003 47.196877000...
# 905  2008-03-31 02:54:22.5  POLYGON J2000 202.46292799999992 47.1769380000...
# 906  2005-11-12 23:54:22.5  POLYGON J2000 202.402459999999991 47.161907000...
# 907  2005-07-21 08:15:00.0  POLYGON J2000 202.466604999999902 47.181218000...
#
#         target_name
# 0          SN2005CS
# 1          M51-ULX2
# 2          SN-1994I
# 3          SN2005CS
# 4    M51-WFPC2-POS3
# 5         SN-2005CS
# 6              M-51
# 7          M51-ULX2
# 8         SN-2011DH
# 9       M51-NUCLEUS
# 10            M51-2
# 11            M51-2
# 12              ANY
# 13   M51-WFPC2-POS3
# 14         SN2005CS
# 15         M51-ULX1
# 16            M51-3
# 17              M51
# 18         M51-POS5
# 19         SN2005CS
# 20          SN1994I
# 21         M51-POS4
# 22         SN2005CS
# 23             M-51
# 24         M-51-V08
# 25         M-51-V03
# 26         M51-POS3
# 27         M-51-V04
# 28            M51-5
# 29         M51-POS5
# ..              ...
# 878        M51-POS5
# 879       SN-2011DH
# 880     M51-NUCLEUS
# 881        M51-POS5
# 882             ANY
# 883     EARTH-CALIB
# 884        SN2005CS
# 885        M-51-V02
# 886       NGC5194-1
# 887            M-51
# 888        SN2005CS
# 889        M-51-V05
# 890       SN-2011DH
# 891        SN2005CS
# 892            M-51
# 893        M51-ULX2
# 894           M51-2
# 895  M51-WFPC2-POS5
# 896           M51-1
# 897        M51-POS6
# 898        M51-ULX2
# 899            M-51
# 900        SN2005CS
# 901       SN-2005CS
# 902        M51-POS5
# 903        M51-POS6
# 904          M51-SW
# 905       SN-2005CS
# 906  M51-WFPC2-POS6
# 907        SN2005CS
#
# [908 rows x 12 columns]

# %%
esasky.plotCatalogues('AllWise')
# Out:
# Catalogs from missionId: AllWise displayed in the ESASky

# %%
esasky.plotSpectra('Herschel')
# Out:
# Spectra from missionId: Herschel displayed in the ESASky

# %% [markdown]
# ## Get all information about the HiPS available in ESASky

# %% [markdown]
# Either by gettig all wavelengths or just for one specific

# %%
esasky.getAvailableHiPS()
# Out:
# {'GAMMA_RAY': {'Fermi color': {'mission': 'FERMI',
#    'missionURL': 'http://fermi.gsfc.nasa.gov/',
#    'wavelengthRange': '30 MeV - 10 GeV',
#    'instrument': '',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2013-06-28T11:09Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/Fermi/Color/properties',
#    'surveyId': 'Fermi color',
#    'surveyName': 'Fermi color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/FermiColor/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': True,
#    'icon': 'nasa_logo.png',
#    'colorPalette': 'NATIVE'}},
#  'HARD_X_RAY': {'INTEGRAL-IBIS RGB': {'mission': 'INTEGRAL',
#    'missionURL': 'http://www.cosmos.esa.int/web/integral',
#    'wavelengthRange': '15 keV - 1 MeV',
#    'instrument': 'IBIS',
#    'creator': 'European Space Agency (INTEGRAL Science Operations Centre & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T10:10Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#INTEGRAL',
#    'surveyId': 'INTEGRAL-IBIS RGB',
#    'surveyName': 'INTEGRAL-IBIS RGB',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Integral/color/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': True,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'INTEGRAL-IBIS 20-35 keV': {'mission': 'INTEGRAL',
#    'missionURL': 'http://www.cosmos.esa.int/web/integral',
#    'wavelengthRange': '20-35 keV',
#    'instrument': 'IBIS',
#    'creator': 'European Space Agency (INTEGRAL Science Operations Centre & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2016-05-12T08:59Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#INTEGRAL',
#    'surveyId': 'INTEGRAL-IBIS 20-35 keV',
#    'surveyName': 'INTEGRAL-IBIS 20-35 keV',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Integral/20-35/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'INTEGRAL-IBIS 35-65 keV': {'mission': 'INTEGRAL',
#    'missionURL': 'http://www.cosmos.esa.int/web/integral',
#    'wavelengthRange': '35-65 keV',
#    'instrument': 'IBIS',
#    'creator': 'European Space Agency (INTEGRAL Science Operations Centre & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T10:10Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#INTEGRAL',
#    'surveyId': 'INTEGRAL-IBIS 35-65 keV',
#    'surveyName': 'INTEGRAL-IBIS 35-65 keV',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Integral/35-65/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'INTEGRAL-IBIS 65-100 keV': {'mission': 'INTEGRAL',
#    'missionURL': 'http://www.cosmos.esa.int/web/integral',
#    'wavelengthRange': '65-100 keV',
#    'instrument': 'IBIS',
#    'creator': 'European Space Agency (INTEGRAL Science Operations Centre & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T10:10Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#INTEGRAL',
#    'surveyId': 'INTEGRAL-IBIS 65-100 keV',
#    'surveyName': 'INTEGRAL-IBIS 65-100 keV',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Integral/65-100/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Swift-BAT RGB': {'mission': 'Swift',
#    'missionURL': 'http://swift.gsfc.nasa.gov/',
#    'wavelengthRange': '14 keV - 194 keV',
#    'instrument': 'BAT',
#    'creator': 'Japan Aerospace eXploration Agency (JAXA)',
#    'creatorURL': 'http://global.jaxa.jp/',
#    'creationDate': '2015-04-17T07:39Z',
#    'moreInfoURL': 'http://skies.esac.esa.int/swift_bat_flux/properties',
#    'surveyId': 'Swift-BAT RGB',
#    'surveyName': 'Swift-BAT RGB',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/swift_bat_flux/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 6,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'nasa_logo.png',
#    'colorPalette': 'NATIVE'}},
#  'SOFT_X_RAY': {'Chandra RGB': {'mission': 'Chandra',
#    'missionURL': 'http://chandra.harvard.edu/',
#    'wavelengthRange': '',
#    'instrument': 'ALL',
#    'creator': 'Harvard-Smithsonian Center for Astrophysics (CfA)',
#    'creatorURL': 'https://www.cfa.harvard.edu',
#    'creationDate': '2019-05-30T13:29Z',
#    'moreInfoURL': 'https://cdaftp.cfa.harvard.edu/cxc-hips/properties',
#    'surveyId': 'Chandra RGB',
#    'surveyName': 'Chandra RGB',
#    'surveyRootUrl': 'https://cdaftp.cfa.harvard.edu/cxc-hips/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 11,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'nasa_logo.png',
#    'colorPalette': 'NATIVE'},
#   'XMM-Newton EPIC color': {'mission': 'XMM-Newton',
#    'missionURL': 'http://www.cosmos.esa.int/web/xmm-newton',
#    'wavelengthRange': '0.12 - 12 keV',
#    'instrument': 'EPIC',
#    'creator': 'European Space Agency (XMM-Newton Science Operations Centre & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#XMM',
#    'surveyId': 'XMM-Newton EPIC color',
#    'surveyName': 'XMM-Newton EPIC color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/XMM-Newton/EPIC-RGB/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 7,
#    'imgFormat': 'jpg',
#    'isDefault': True,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'SUZAKU': {'mission': 'Suzaku',
#    'missionURL': 'http://global.jaxa.jp/projects/sat/astro_e2/',
#    'wavelengthRange': '0.2 - 12 keV',
#    'instrument': 'XIS',
#    'creator': 'Japan Aerospace eXploration Agency (JAXA)',
#    'creatorURL': 'http://global.jaxa.jp/',
#    'creationDate': '',
#    'moreInfoURL': 'http://skies.esac.esa.int/suzaku/properties',
#    'surveyId': 'SUZAKU',
#    'surveyName': 'SUZAKU',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/suzaku/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 6,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'jaxa.png',
#    'colorPalette': 'NATIVE'},
#   'EXOSAT-LE': {'mission': 'EXOSAT',
#    'missionURL': 'http://www.cosmos.esa.int/web/exosat',
#    'wavelengthRange': '0.5 - 2 keV',
#    'instrument': 'LE (CMA1 & CMA2)',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2016-03-09T14:07Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#EXOSAT',
#    'surveyId': 'EXOSAT-LE',
#    'surveyName': 'EXOSAT-LE',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/EXOSAT/LE/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'CUBEHELIX'}},
#  'UV': {'GALEX GR6 AIS color': {'mission': 'GALEX',
#    'missionURL': 'http://galex.stsci.edu/GR6/',
#    'wavelengthRange': '1350 - 2730 &Aring;',
#    'instrument': 'AIS',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/GALEX/GR6-03-2014/AIS-Color/properties',
#    'surveyId': 'GALEX GR6 AIS color',
#    'surveyName': 'GALEX GR6 AIS color',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/GALEX/GR6-03-2014/AIS-Color/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 8,
#    'imgFormat': 'png',
#    'isDefault': True,
#    'icon': 'nasa_logo.png',
#    'colorPalette': 'NATIVE'},
#   'XMM-Newton UV color': {'mission': 'XMM-Newton',
#    'missionURL': 'http://www.cosmos.esa.int/web/xmm-newton',
#    'wavelengthRange': '180 - 320 nm ',
#    'instrument': 'OM',
#    'creator': 'European Space Agency (XMM-Newton Science Operations Centre & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-17T19:13Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#XMM',
#    'surveyId': 'XMM-Newton UV color',
#    'surveyName': 'XMM-Newton UV color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/XMM-Newton/OMX_LMS-bkg/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'}},
#  'OPTICAL': {'DSS2 color': {'mission': 'Digitized Sky Survey',
#    'missionURL': 'http://archive.stsci.edu/dss/',
#    'wavelengthRange': '',
#    'instrument': 'POSS-II, AAO and SERC plates',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2010-05-01T19:05Z ',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/DSS/DSSColor/properties',
#    'surveyId': 'DSS2 color',
#    'surveyName': 'DSS2 color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/DSSColor/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'jpg',
#    'isDefault': True,
#    'icon': 'cds.png',
#    'colorPalette': 'NATIVE'},
#   'DSS2 red': {'mission': 'Digitized Sky Survey',
#    'missionURL': 'http://archive.stsci.edu/dss/',
#    'wavelengthRange': '~658 nm',
#    'instrument': 'POSS-II F, AAO-SES,SR and SERC-ER plates',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2012-07-13T14:03Z ',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/DSS/DSS2Merged/properties',
#    'surveyId': 'DSS2 red',
#    'surveyName': 'DSS2 red',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/DSS/DSS2Merged/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'cds.png',
#    'colorPalette': 'NATIVE'},
#   'HST ACS': {'mission': 'HST',
#    'missionURL': 'http://archives.esac.esa.int/ehst/',
#    'wavelengthRange': '1150 - 11000 &Aring;',
#    'instrument': 'ACS',
#    'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-18T14:01Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#    'surveyId': 'HST ACS',
#    'surveyName': 'HST ACS',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/ACS/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 13,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'HST WFPC2': {'mission': 'HST',
#    'missionURL': 'http://archives.esac.esa.int/ehst/',
#    'wavelengthRange': '1150 - 11000 &Aring;',
#    'instrument': 'WFPC2',
#    'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-24T17:38Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#    'surveyId': 'HST WFPC2',
#    'surveyName': 'HST WFPC2',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/WFPC2/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 13,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'HST WFC3': {'mission': 'HST',
#    'missionURL': 'http://archives.esac.esa.int/ehst/',
#    'wavelengthRange': '1150 - 11000 &Aring;',
#    'instrument': 'WFC3',
#    'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T10:02Z ',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#    'surveyId': 'HST WFC3',
#    'surveyName': 'HST WFC3',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/WFC3/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 14,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'HST FOC': {'mission': 'HST',
#    'missionURL': 'http://archives.esac.esa.int/ehst/',
#    'wavelengthRange': '1150 - 6500 &Aring;',
#    'instrument': 'FOC',
#    'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-30T11:05Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#    'surveyId': 'HST FOC',
#    'surveyName': 'HST FOC',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/FOC/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 15,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'HST WFPC': {'mission': 'HST',
#    'missionURL': 'http://archives.esac.esa.int/ehst/',
#    'wavelengthRange': '1150 - 11000 &Aring;',
#    'instrument': 'WFPC',
#    'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-30T12:15Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#    'surveyId': 'HST WFPC',
#    'surveyName': 'HST WFPC',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/WFPC/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 12,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'XMM UBV color': {'mission': 'XMM-Newton',
#    'missionURL': 'http://www.cosmos.esa.int/web/xmm-newton',
#    'wavelengthRange': '300 - 580 nm',
#    'instrument': 'OM',
#    'creator': 'European Space Agency (XMM-Newton Science Operations Centre & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-17T17:43Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#XMM',
#    'surveyId': 'XMM UBV color',
#    'surveyName': 'XMM UBV color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/XMM-Newton/OMX_UBV-bkg/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'SDSS9 color': {'mission': 'Sloan Digital Sky Survey',
#    'missionURL': 'http://www.sdss.org',
#    'wavelengthRange': '3594.9 - 10833 &Aring;',
#    'instrument': 'SDSS imaging camera',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2013-12-18T09:42Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/SDSS/DR9/color/properties',
#    'surveyId': 'SDSS9 color',
#    'surveyName': 'SDSS9 color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/SDSS9Color/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'sdss_logo.png',
#    'colorPalette': 'NATIVE'},
#   'SuperCOSMOS H alpha': {'mission': 'SuperCOSMOS',
#    'missionURL': 'http://www-wfau.roe.ac.uk/sss/halpha/',
#    'wavelengthRange': '6590 &Aring;',
#    'instrument': 'UKST plates',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2014-03-01T01:07Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/SHS/properties',
#    'surveyId': 'SuperCOSMOS H alpha',
#    'surveyName': 'SuperCOSMOS H alpha',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/SHS/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'cds.png',
#    'colorPalette': 'NATIVE'},
#   'VTSS Ha': {'mission': 'The Virginia Tech Spectral-Line Survey',
#    'missionURL': 'http://www.phys.vt.edu/~halpha/',
#    'wavelengthRange': '6563 &Aring;',
#    'instrument': 'SLIC',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2013-09-16T10:05Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/VTSS/Ha/properties',
#    'surveyId': 'VTSS Ha',
#    'surveyName': 'VTSS Ha',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/VTSSHa/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'cds.png',
#    'colorPalette': 'NATIVE'},
#   'Mellinger color': {'mission': 'Mellinger optical survey',
#    'missionURL': 'http://www.milkywaysky.com/',
#    'wavelengthRange': '370 - 700 nm',
#    'instrument': 'SBIG STL-11000 camera',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2010-07-12T00:00Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/MellingerRGB/properties',
#    'surveyId': 'Mellinger color',
#    'surveyName': 'Mellinger color',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/MellingerRGB/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 4,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'cds.png',
#    'colorPalette': 'NATIVE'},
#   'Finkbeiner Ha': {'mission': 'Finkbeiner Halpha composite survey',
#    'missionURL': 'http://lambda.gsfc.nasa.gov/product/foreground/halpha_map.cfm',
#    'wavelengthRange': '6563 &Aring;',
#    'instrument': 'VT SLIC, WHAM, CCD @1m telescope on CTIO',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2010-12-14T01:07Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/FinkbeinerHalpha/properties',
#    'surveyId': 'Finkbeiner Ha',
#    'surveyName': 'Finkbeiner Ha',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/FinkbeinerHa/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'cds.png',
#    'colorPalette': 'NATIVE'}},
#  'NEAR_IR': {'2MASS color JHK': {'mission': '2MASS',
#    'missionURL': 'http://www.ipac.caltech.edu/2mass/',
#    'wavelengthRange': '10806 - 23552 &Aring;',
#    'instrument': '2MASS 3-channel cameras',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2012-02-24T12:43Z ',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/2MASS/Color/properties',
#    'surveyId': '2MASS color JHK',
#    'surveyName': '2MASS color JHK',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/2MASSColor/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'jpg',
#    'isDefault': True,
#    'icon': '2mass_logo.gif',
#    'colorPalette': 'NATIVE'},
#   'HST NICMOS': {'mission': 'HST',
#    'missionURL': 'http://archives.esac.esa.int/ehst/',
#    'wavelengthRange': '0.8 - 2.5 &micro;m',
#    'instrument': 'NICMOS',
#    'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-23T00:40Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#    'surveyId': 'HST NICMOS',
#    'surveyName': 'HST NICMOS',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/NICMOS/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 16,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'}},
#  'MID_IR': {'Spitzer cold SEIP IRAC-1-3-4 RGB bright': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '3.6 - 7.9 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ISO Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2018-10-08T17:05Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC-1-3-4 RGB bright',
#    'surveyName': 'Spitzer cold SEIP IRAC-1-3-4 RGB bright',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC134_RGB_bright/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC1 faint': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '3.6 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC1 faint',
#    'surveyName': 'Spitzer cold SEIP IRAC1 faint',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC1_faint_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC2 faint': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '4.5 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC2 faint',
#    'surveyName': 'Spitzer cold SEIP IRAC2 faint',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC2_faint_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC3 faint': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '5.8 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC3 faint',
#    'surveyName': 'Spitzer cold SEIP IRAC3 faint',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC3_faint_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC4 faint': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '7.9 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC4 faint',
#    'surveyName': 'Spitzer cold SEIP IRAC4 faint',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC4_faint_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC1 bright': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '3.6 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC1 bright',
#    'surveyName': 'Spitzer cold SEIP IRAC1 bright',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC1_bright_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC2 bright': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '4.5 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC2 bright',
#    'surveyName': 'Spitzer cold SEIP IRAC2 bright',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC2_bright_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC3 bright': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '5.8 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC3 bright',
#    'surveyName': 'Spitzer cold SEIP IRAC3 bright',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC3_bright_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Spitzer cold SEIP IRAC4 bright': {'mission': 'Spitzer',
#    'missionURL': 'https://sha.ipac.caltech.edu/applications/Spitzer/SHA/',
#    'wavelengthRange': '7.9 &micro;m',
#    'instrument': 'IRAC',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#SPITZER',
#    'surveyId': 'Spitzer cold SEIP IRAC4 bright',
#    'surveyName': 'Spitzer cold SEIP IRAC4 bright',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Spitzer/IRAC4_bright_ISM',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 10,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'AllWISE color': {'mission': 'WISE',
#    'missionURL': 'http://wise2.ipac.caltech.edu/docs/release/allsky/',
#    'wavelengthRange': '27541 - 279107 &Aring;',
#    'instrument': 'WISE imager',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2014-04-15T08:59Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/AllWISE/RGB-W4-W2-W1/properties',
#    'surveyId': 'AllWISE color',
#    'surveyName': 'AllWISE color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/AllWISEColor/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 8,
#    'imgFormat': 'jpg',
#    'isDefault': True,
#    'icon': 'nasa_logo.png',
#    'colorPalette': 'NATIVE'},
#   'ISOCAM': {'mission': 'ISO',
#    'missionURL': 'https://www.cosmos.esa.int/web/iso',
#    'wavelengthRange': '3 - 18 &micro;m ',
#    'instrument': 'CAM ',
#    'creator': 'European Space Agency (ISO Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-09T10:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#ISO',
#    'surveyId': 'ISOCAM',
#    'surveyName': 'ISOCAM',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/ISO/CAM/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 8,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'}},
#  'FAR_IR': {'Herschel PACS 70 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '70 micron',
#    'instrument': 'PACS',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-26T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel PACS 70 micron',
#    'surveyName': 'Herschel PACS 70 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/PACS_hips70/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Herschel PACS 100 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '100 micron',
#    'instrument': 'PACS',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-26T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel PACS 100 micron',
#    'surveyName': 'Herschel PACS 100 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/PACS_hips100/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Herschel PACS 160 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '160 micron',
#    'instrument': 'PACS',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-26T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel PACS 160 micron',
#    'surveyName': 'Herschel PACS 160 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/PACS_hips160/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 8,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Herschel PACS RGB 70, 160 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '70 - 160 &micro;m',
#    'instrument': 'PACS',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-26T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel PACS RGB 70, 160 micron',
#    'surveyName': 'Herschel PACS RGB 70, 160 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/PACS_hipsRGB/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'png',
#    'isDefault': True,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Herschel PACS RGB Gal. plane': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '70 - 160 &micro;m',
#    'instrument': 'PACS',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-14T09:26Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel PACS RGB Gal. plane',
#    'surveyName': 'Herschel PACS RGB Gal. plane',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/PACS-color/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 9,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'All Herschel color': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel',
#    'wavelengthRange': '70 - 500 &micro;m',
#    'instrument': 'PACS, SPIRE',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-14T17:02Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'All Herschel color',
#    'surveyName': 'All Herschel color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/color/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 8,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'AKARI FIS color': {'mission': 'AKARI',
#    'missionURL': 'http://www.ir.isas.jaxa.jp/AKARI/',
#    'wavelengthRange': '65 - 160 &micro;m',
#    'instrument': 'FIS',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T13:06Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#AKARI',
#    'surveyId': 'AKARI FIS color',
#    'surveyName': 'AKARI FIS color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/AKARI/color/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'jaxa.png',
#    'colorPalette': 'NATIVE'},
#   'AKARI N60': {'mission': 'AKARI',
#    'missionURL': 'http://www.ir.isas.jaxa.jp/AKARI/',
#    'wavelengthRange': '65 &micro;m',
#    'instrument': 'FIS',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T07:38Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#AKARI',
#    'surveyId': 'AKARI N60',
#    'surveyName': 'AKARI N60',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/AKARI/N60/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'jaxa.png',
#    'colorPalette': 'NATIVE'},
#   'AKARI WideS': {'mission': 'AKARI',
#    'missionURL': 'http://www.ir.isas.jaxa.jp/AKARI/',
#    'wavelengthRange': '90 &micro;m',
#    'instrument': 'FIS',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T07:04Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#AKARI',
#    'surveyId': 'AKARI WideS',
#    'surveyName': 'AKARI WideS',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/AKARI/WideS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'jaxa.png',
#    'colorPalette': 'NATIVE'},
#   'AKARI WideL': {'mission': 'AKARI',
#    'missionURL': 'http://www.ir.isas.jaxa.jp/AKARI/',
#    'wavelengthRange': '140 &micro;m',
#    'instrument': 'FIS',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T08:06Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#AKARI',
#    'surveyId': 'AKARI WideL',
#    'surveyName': 'AKARI WideL',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/AKARI/WideL/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'jaxa.png',
#    'colorPalette': 'NATIVE'},
#   'AKARI N160': {'mission': 'AKARI',
#    'missionURL': 'http://www.ir.isas.jaxa.jp/AKARI/',
#    'wavelengthRange': '160 &micro;m',
#    'instrument': 'FIS',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-10-13T07:06Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#AKARI',
#    'surveyId': 'AKARI N160',
#    'surveyName': 'AKARI N160',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/AKARI/N160/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'jaxa.png',
#    'colorPalette': 'NATIVE'},
#   'IRIS color': {'mission': 'IRAS',
#    'missionURL': 'http://irsa.ipac.caltech.edu/data/IRIS/',
#    'wavelengthRange': '12 - 100 &micro;m',
#    'instrument': 'IRAS',
#    'creator': 'Centre de Donees Astronomiques d’Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2010-06-09T06:33Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/IRISColor/properties',
#    'surveyId': 'IRIS color',
#    'surveyName': 'IRIS color',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/IRISColor/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'nasa_logo.png',
#    'colorPalette': 'NATIVE'}},
#  'SUBMM': {'Herschel SPIRE 250 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '250 &micro;m',
#    'instrument': 'SPIRE',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-01T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel SPIRE 250 micron',
#    'surveyName': 'Herschel SPIRE 250 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/hips250_pnorm_allsky/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 7,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Herschel SPIRE 350 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '350 &micro;m',
#    'instrument': 'SPIRE',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-01T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel SPIRE 350 micron',
#    'surveyName': 'Herschel SPIRE 350 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/hips350_pnorm_allsky/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 6,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Herschel SPIRE 500 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '500 &micro;m',
#    'instrument': 'SPIRE',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-01T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel SPIRE 500 micron',
#    'surveyName': 'Herschel SPIRE 500 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/hips500_pnorm_allsky/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 5,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Herschel SPIRE RGB 250, 350, 500 micron': {'mission': 'Herschel',
#    'missionURL': 'https://www.cosmos.esa.int/web/herschel/home',
#    'wavelengthRange': '250 - 500 &micro;m',
#    'instrument': 'SPIRE',
#    'creator': 'European Space Agency (Herschel Science Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-09-01T14:00Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/esdc/esasky-skies#HERSCHEL',
#    'surveyId': 'Herschel SPIRE RGB 250, 350, 500 micron',
#    'surveyName': 'Herschel SPIRE RGB 250, 350, 500 micron',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Herschel/normalized/SPIRE_pnorm_RGB/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 7,
#    'imgFormat': 'png',
#    'isDefault': True,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'NATIVE'},
#   'Planck HFI 857 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '857 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T15:21:00Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 857 GHz',
#    'surveyName': 'Planck HFI 857 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_857_2048_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 545 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '545 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T15:16:33Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 545 GHz',
#    'surveyName': 'Planck HFI 545 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_545_2048_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 353 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '353 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T15:10:46Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 353 GHz',
#    'surveyName': 'Planck HFI 353 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_353-psb_2048_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 353 GHz Pol smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '353 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 353 GHz Pol smoothed',
#    'surveyName': 'Planck HFI 353 GHz Pol smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_353-psb_2048_R3_00_full_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'}},
#  'RADIO': {'Planck HFI 217 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '217 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T15:05:18Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 217 GHz',
#    'surveyName': 'Planck HFI 217 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_217_2048_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 143 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '143 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T14:59:48Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 143 GHz',
#    'surveyName': 'Planck HFI 143 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_143_2048_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 100 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '100 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-22T14:54:21Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 100 GHz',
#    'surveyName': 'Planck HFI 100 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_100_2048_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck LFI 070 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '70 GHz',
#    'instrument': 'LFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T18:01:56Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck LFI 070 GHz',
#    'surveyName': 'Planck LFI 070 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/LFI_SkyMap_070_1024_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck LFI 044 GHz': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '44 GHz',
#    'instrument': 'LFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T17:17:41Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck LFI 044 GHz',
#    'surveyName': 'Planck LFI 044 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/LFI_SkyMap_044_1024_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck LFI 030 GHz': {'mission': 'PLANCK',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '30 GHz',
#    'instrument': 'LFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck LFI 030 GHz',
#    'surveyName': 'Planck LFI 030 GHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/LFI_SkyMap_030_1024_R3_00_full_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': True,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 217 GHz Pol smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '217 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 217 GHz Pol smoothed',
#    'surveyName': 'Planck HFI 217 GHz Pol smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_217_2048_R3_00_full_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 143 GHz Pol smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '143 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 143 GHz Pol smoothed',
#    'surveyName': 'Planck HFI 143 GHz Pol smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_143_2048_R3_00_full_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck HFI 100 GHz Pol smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '100 GHz',
#    'instrument': 'HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck HFI 100 GHz Pol smoothed',
#    'surveyName': 'Planck HFI 100 GHz Pol smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/HFI_SkyMap_100_2048_R3_00_full_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck LFI 070 GHz Pol smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '70 GHz',
#    'instrument': 'LFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck LFI 070 GHz Pol smoothed',
#    'surveyName': 'Planck LFI 070 GHz Pol smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/LFI_SkyMap_070_1024_R3_00_full_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck LFI 044 GHz Pol smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '44 GHz',
#    'instrument': 'LFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck LFI 044 GHz Pol smoothed',
#    'surveyName': 'Planck LFI 044 GHz Pol smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/LFI_SkyMap_044_1024_R3_00_full_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck LFI 030 GHz Pol smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '30 GHz',
#    'instrument': 'LFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2015-09-15T16:16:19Z',
#    'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#PLANCK',
#    'surveyId': 'Planck LFI 030 GHz Pol smoothed',
#    'surveyName': 'Planck LFI 030 GHz Pol smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/LFI_SkyMap_030_1024_R3_00_full_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'CO composite survey': {'mission': 'Composite CO(1-0) map constructed by Dame et al.(2001) from 37 individual surveys of the Galaxy.',
#    'missionURL': 'http://dx.doi.org/10.1086/318388',
#    'wavelengthRange': '115 GHz',
#    'instrument': 'See Dame, Hartmann and Thaddeus (2001), ApJ, 547, 792',
#    'creator': 'LAMBDA',
#    'creatorURL': 'http://lambda.gsfc.nasa.gov/',
#    'creationDate': '2011-02-14T12:00Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/CO/properties',
#    'surveyId': 'CO composite survey',
#    'surveyName': 'CO composite survey',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/CO/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'nasa_logo.png',
#    'colorPalette': 'NATIVE'},
#   'CHIPASS 1.4GHz': {'mission': 'Reprocessing of archival data from the HI Parkes All-Sky Survey (HIPASS) and the HI Zone of Avoidance (HIZOA) survey.',
#    'missionURL': 'http://cade.irap.omp.eu/dokuwiki/doku.php?id=chipass',
#    'wavelengthRange': '1.4 GHz (21 cm)',
#    'instrument': 'The Parkes 21 cm Multibeam Receiver and Parkes 64 m telescope',
#    'creator': 'IRAP/CADE',
#    'creatorURL': 'http://cade.irap.omp.eu',
#    'creationDate': '2014-07-08T16:43Z',
#    'moreInfoURL': 'http://cade.irap.omp.eu/documents/Ancillary/4Aladin/CHIPASS/properties',
#    'surveyId': 'CHIPASS 1.4GHz',
#    'surveyName': 'CHIPASS 1.4GHz',
#    'surveyRootUrl': 'http://cade.irap.omp.eu/documents/Ancillary/4Aladin/CHIPASS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'irap_logo.png',
#    'colorPalette': 'NATIVE'},
#   'NVSS intensity maps': {'mission': 'The NRAO VLA Sky Survey (intensity maps), a 1.4 GHz continuum survey covering the entire northern hemisphere.',
#    'missionURL': 'http://www.cv.nrao.edu/nvss/',
#    'wavelengthRange': '1.4 GHz (21 cm)',
#    'instrument': 'The Very Large Array (VLA)',
#    'creator': 'Centre de Donnees astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2015-04-07T13:09Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/NVSS/intensity/properties',
#    'surveyId': 'NVSS intensity maps',
#    'surveyName': 'NVSS intensity maps',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/NVSS/intensity/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 5,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'nrao_logo.png',
#    'colorPalette': 'NATIVE'},
#   'CGPS-VGPS CONT': {'mission': 'Combination of the 1420 MHz continuum of the Canadian Galactic Plane Survey (CGPS) with the VLA Galactic Plane Survey (VGPS).',
#    'missionURL': 'http://cade.irap.omp.eu',
#    'wavelengthRange': '1.4 GHz (21 cm)',
#    'instrument': 'The Dominion Radio Astrophysical Observatory (DRAO) and the NRAO VLA telescope',
#    'creator': 'IRAP/CADE',
#    'creatorURL': 'http://cade.irap.omp.eu',
#    'creationDate': '2013-10-07T15:21Z',
#    'moreInfoURL': 'http://cade.irap.omp.eu/documents/Ancillary/4Aladin/CGPS_VGPS_CONT/properties',
#    'surveyId': 'CGPS-VGPS CONT',
#    'surveyName': 'CGPS-VGPS CONT',
#    'surveyRootUrl': 'http://cade.irap.omp.eu/documents/Ancillary/4Aladin/CGPS_VGPS_CONT/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 4,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'irap_logo.png',
#    'colorPalette': 'NATIVE'},
#   'GASS NH': {'mission': "Parkes Galactic All Sky Survey (GASS). 21 cm emission from Galactic neutral hydrogen, at a resolution of 16'.",
#    'missionURL': 'http://cade.irap.omp.eu/dokuwiki/doku.php?id=gass',
#    'wavelengthRange': '1.4 GHz (21 cm)',
#    'instrument': 'The Parkes Radio telescope',
#    'creator': 'IRAP/CADE',
#    'creatorURL': 'http://cade.irap.omp.eu',
#    'creationDate': '2014-07-08T16:10Z',
#    'moreInfoURL': 'http://cade.irap.omp.eu/documents/Ancillary/4Aladin/GASS/properties',
#    'surveyId': 'GASS NH',
#    'surveyName': 'GASS NH',
#    'surveyRootUrl': 'http://cade.irap.omp.eu/documents/Ancillary/4Aladin/GASS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'irap_logo.png',
#    'colorPalette': 'NATIVE'},
#   'HI4PI NHI': {'mission': 'The HI4PI data release comprises 21-cm neutral atomic hydrogen data of the Milky Way',
#    'missionURL': 'http://cade.irap.omp.eu/dokuwiki/doku.php?id=hi4pi',
#    'wavelengthRange': '1.4 GHz (21 cm)',
#    'instrument': '100-m radio telescope at Effelsberg and the 64-m radio telescope at Parkes',
#    'creator': 'M.Buga [CDS]',
#    'creatorURL': 'http://cds.u-strasbg.fr/',
#    'creationDate': '2017-06-12T13:36Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/HI4PI/P_HI4PI_NHI/properties',
#    'surveyId': 'HI4PI NHI',
#    'surveyName': 'HI4PI NHI',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HI4PI/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'irap_logo.png',
#    'colorPalette': 'NATIVE'},
#   'SUMSS 843 MHz': {'mission': 'The Sydney University Molonglo Sky Survey (SUMSS)',
#    'missionURL': 'http://cade.irap.omp.eu/dokuwiki/doku.php?id=sumss',
#    'wavelengthRange': '843 MHz (35 cm)',
#    'instrument': 'The Molonglo Observatory Synthesis Telescope',
#    'creator': 'IRAP/CADE',
#    'creatorURL': 'http://cade.irap.omp.eu',
#    'creationDate': '2015-02-02T11:18Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/SUMSS/properties',
#    'surveyId': 'SUMSS 843 MHz',
#    'surveyName': 'SUMSS 843 MHz',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/SUMSS/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 6,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'irap_logo.png',
#    'colorPalette': 'NATIVE'},
#   'Haslam 408 MHz': {'mission': 'Haslam 408 MHz',
#    'missionURL': 'https://lambda.gsfc.nasa.gov/product/foreground/fg_2014_haslam_408_info.cfm',
#    'wavelengthRange': '408 MHz',
#    'instrument': 'Bonn ECP Grid -- MPIfR Survey Sampler',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-08-08T06:01Z',
#    'moreInfoURL': 'https://lambda.gsfc.nasa.gov/product/foreground/fg_2014_haslam_408_info.cfm',
#    'surveyId': 'Haslam 408 MHz',
#    'surveyName': 'Haslam 408 MHz',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Haslam/Haslam_DSonly_2014/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Haslam 408 MHz (Desourced)': {'mission': 'Haslam 408 MHz (Desourced)',
#    'missionURL': 'https://lambda.gsfc.nasa.gov/product/foreground/fg_2014_haslam_408_info.cfm',
#    'wavelengthRange': '408 MHz',
#    'instrument': 'Bonn ECP Grid -- MPIfR Survey Sampler',
#    'creator': 'European Space Agency (ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-08-08T06:01Z',
#    'moreInfoURL': 'https://lambda.gsfc.nasa.gov/product/foreground/fg_2014_haslam_408_info.cfm',
#    'surveyId': 'Haslam 408 MHz (Desourced)',
#    'surveyName': 'Haslam 408 MHz (Desourced)',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/Haslam/Haslam408_dsds_Remazeilles2014_mod_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'WENSS 325 MHz': {'mission': 'The Westerbork Northern Sky Survey (WENSS)',
#    'missionURL': 'https://openaccess.leidenuniv.nl/bitstream/handle/1887/7485/A%26AS_124_259_280.pdf',
#    'wavelengthRange': '325 MHz (92 cm)',
#    'instrument': 'The Westerbork Synthesis Radio Telescope',
#    'creator': 'Centre de Donnees&eacute;es astronomiques de Strasbourg',
#    'creatorURL': 'http://cdsweb.u-strasbg.fr',
#    'creationDate': '2012-04-25T14:03Z',
#    'moreInfoURL': 'http://alasky.u-strasbg.fr/WENSS/properties',
#    'surveyId': 'WENSS 325 MHz',
#    'surveyName': 'WENSS 325 MHz',
#    'surveyRootUrl': 'http://alasky.u-strasbg.fr/WENSS/',
#    'surveyFrame': 'EQUATORIAL',
#    'maximumNorder': 5,
#    'imgFormat': 'jpg',
#    'isDefault': False,
#    'icon': 'astron_logo.png',
#    'colorPalette': 'NATIVE'}},
#  'OTHERS': {'Planck Pol Dust smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '30 - 857 GHz',
#    'instrument': 'LFI+HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-08-08T12:57Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/planck',
#    'surveyId': 'Planck Pol Dust smoothed',
#    'surveyName': 'Planck Pol Dust smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/COM_CompMap_DustPol-commander_1024_R2.00_P_smooth_10amin_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': True,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'},
#   'Planck Pol Synchrotron smoothed': {'mission': 'Planck',
#    'missionURL': 'https://www.cosmos.esa.int/web/planck',
#    'wavelengthRange': '30 - 857 GHz',
#    'instrument': 'LFI+HFI',
#    'creator': 'European Space Agency (Planck Legacy Archive & ESAC Science Data Centre)',
#    'creatorURL': 'http://www.esa.int/',
#    'creationDate': '2017-08-08T09:51Z',
#    'moreInfoURL': 'https://www.cosmos.esa.int/web/planck',
#    'surveyId': 'Planck Pol Synchrotron smoothed',
#    'surveyName': 'Planck Pol Synchrotron smoothed',
#    'surveyRootUrl': 'http://cdn.skies.esac.esa.int/pla/COM_CompMap_SynchrotronPol-commander_0512_R2.00_P_smooth_HiPS/',
#    'surveyFrame': 'GALACTIC',
#    'maximumNorder': 3,
#    'imgFormat': 'png',
#    'isDefault': False,
#    'icon': 'esaLogo.png',
#    'colorPalette': 'PLANCK'}}}

# %%
esasky.getAvailableHiPS('OPTICAL')
# Out:
# {'DSS2 color': {'mission': 'Digitized Sky Survey',
#   'missionURL': 'http://archive.stsci.edu/dss/',
#   'wavelengthRange': '',
#   'instrument': 'POSS-II, AAO and SERC plates',
#   'creator': 'Centre de Donnees astronomiques de Strasbourg',
#   'creatorURL': 'http://cdsweb.u-strasbg.fr',
#   'creationDate': '2010-05-01T19:05Z ',
#   'moreInfoURL': 'http://alasky.u-strasbg.fr/DSS/DSSColor/properties',
#   'surveyId': 'DSS2 color',
#   'surveyName': 'DSS2 color',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/DSSColor/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 9,
#   'imgFormat': 'jpg',
#   'isDefault': True,
#   'icon': 'cds.png',
#   'colorPalette': 'NATIVE'},
#  'DSS2 red': {'mission': 'Digitized Sky Survey',
#   'missionURL': 'http://archive.stsci.edu/dss/',
#   'wavelengthRange': '~658 nm',
#   'instrument': 'POSS-II F, AAO-SES,SR and SERC-ER plates',
#   'creator': 'Centre de Donnees astronomiques de Strasbourg',
#   'creatorURL': 'http://cdsweb.u-strasbg.fr',
#   'creationDate': '2012-07-13T14:03Z ',
#   'moreInfoURL': 'http://alasky.u-strasbg.fr/DSS/DSS2Merged/properties',
#   'surveyId': 'DSS2 red',
#   'surveyName': 'DSS2 red',
#   'surveyRootUrl': 'http://alasky.u-strasbg.fr/DSS/DSS2Merged/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 9,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'cds.png',
#   'colorPalette': 'NATIVE'},
#  'HST ACS': {'mission': 'HST',
#   'missionURL': 'http://archives.esac.esa.int/ehst/',
#   'wavelengthRange': '1150 - 11000 &Aring;',
#   'instrument': 'ACS',
#   'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#   'creatorURL': 'http://www.esa.int/',
#   'creationDate': '2015-09-18T14:01Z',
#   'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#   'surveyId': 'HST ACS',
#   'surveyName': 'HST ACS',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/ACS/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 13,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'esaLogo.png',
#   'colorPalette': 'NATIVE'},
#  'HST WFPC2': {'mission': 'HST',
#   'missionURL': 'http://archives.esac.esa.int/ehst/',
#   'wavelengthRange': '1150 - 11000 &Aring;',
#   'instrument': 'WFPC2',
#   'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#   'creatorURL': 'http://www.esa.int/',
#   'creationDate': '2015-09-24T17:38Z',
#   'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#   'surveyId': 'HST WFPC2',
#   'surveyName': 'HST WFPC2',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/WFPC2/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 13,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'esaLogo.png',
#   'colorPalette': 'NATIVE'},
#  'HST WFC3': {'mission': 'HST',
#   'missionURL': 'http://archives.esac.esa.int/ehst/',
#   'wavelengthRange': '1150 - 11000 &Aring;',
#   'instrument': 'WFC3',
#   'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#   'creatorURL': 'http://www.esa.int/',
#   'creationDate': '2015-10-13T10:02Z ',
#   'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#   'surveyId': 'HST WFC3',
#   'surveyName': 'HST WFC3',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/WFC3/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 14,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'esaLogo.png',
#   'colorPalette': 'NATIVE'},
#  'HST FOC': {'mission': 'HST',
#   'missionURL': 'http://archives.esac.esa.int/ehst/',
#   'wavelengthRange': '1150 - 6500 &Aring;',
#   'instrument': 'FOC',
#   'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#   'creatorURL': 'http://www.esa.int/',
#   'creationDate': '2015-09-30T11:05Z',
#   'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#   'surveyId': 'HST FOC',
#   'surveyName': 'HST FOC',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/FOC/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 15,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'esaLogo.png',
#   'colorPalette': 'NATIVE'},
#  'HST WFPC': {'mission': 'HST',
#   'missionURL': 'http://archives.esac.esa.int/ehst/',
#   'wavelengthRange': '1150 - 11000 &Aring;',
#   'instrument': 'WFPC',
#   'creator': 'European Space Agency (European HST Archive & ESAC Science Data Centre)',
#   'creatorURL': 'http://www.esa.int/',
#   'creationDate': '2015-09-30T12:15Z',
#   'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#HST',
#   'surveyId': 'HST WFPC',
#   'surveyName': 'HST WFPC',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/HST/WFPC/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 12,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'esaLogo.png',
#   'colorPalette': 'NATIVE'},
#  'XMM UBV color': {'mission': 'XMM-Newton',
#   'missionURL': 'http://www.cosmos.esa.int/web/xmm-newton',
#   'wavelengthRange': '300 - 580 nm',
#   'instrument': 'OM',
#   'creator': 'European Space Agency (XMM-Newton Science Operations Centre & ESAC Science Data Centre)',
#   'creatorURL': 'http://www.esa.int/',
#   'creationDate': '2015-09-17T17:43Z',
#   'moreInfoURL': 'http://www.cosmos.esa.int/web/esdc/esasky-skies#XMM',
#   'surveyId': 'XMM UBV color',
#   'surveyName': 'XMM UBV color',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/XMM-Newton/OMX_UBV-bkg/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 9,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'esaLogo.png',
#   'colorPalette': 'NATIVE'},
#  'SDSS9 color': {'mission': 'Sloan Digital Sky Survey',
#   'missionURL': 'http://www.sdss.org',
#   'wavelengthRange': '3594.9 - 10833 &Aring;',
#   'instrument': 'SDSS imaging camera',
#   'creator': 'Centre de Donnees astronomiques de Strasbourg',
#   'creatorURL': 'http://cdsweb.u-strasbg.fr',
#   'creationDate': '2013-12-18T09:42Z',
#   'moreInfoURL': 'http://alasky.u-strasbg.fr/SDSS/DR9/color/properties',
#   'surveyId': 'SDSS9 color',
#   'surveyName': 'SDSS9 color',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/SDSS9Color/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 10,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'sdss_logo.png',
#   'colorPalette': 'NATIVE'},
#  'SuperCOSMOS H alpha': {'mission': 'SuperCOSMOS',
#   'missionURL': 'http://www-wfau.roe.ac.uk/sss/halpha/',
#   'wavelengthRange': '6590 &Aring;',
#   'instrument': 'UKST plates',
#   'creator': 'Centre de Donnees astronomiques de Strasbourg',
#   'creatorURL': 'http://cdsweb.u-strasbg.fr',
#   'creationDate': '2014-03-01T01:07Z',
#   'moreInfoURL': 'http://alasky.u-strasbg.fr/SHS/properties',
#   'surveyId': 'SuperCOSMOS H alpha',
#   'surveyName': 'SuperCOSMOS H alpha',
#   'surveyRootUrl': 'http://alasky.u-strasbg.fr/SHS/',
#   'surveyFrame': 'EQUATORIAL',
#   'maximumNorder': 10,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'cds.png',
#   'colorPalette': 'NATIVE'},
#  'VTSS Ha': {'mission': 'The Virginia Tech Spectral-Line Survey',
#   'missionURL': 'http://www.phys.vt.edu/~halpha/',
#   'wavelengthRange': '6563 &Aring;',
#   'instrument': 'SLIC',
#   'creator': 'Centre de Donnees astronomiques de Strasbourg',
#   'creatorURL': 'http://cdsweb.u-strasbg.fr',
#   'creationDate': '2013-09-16T10:05Z',
#   'moreInfoURL': 'http://alasky.u-strasbg.fr/VTSS/Ha/properties',
#   'surveyId': 'VTSS Ha',
#   'surveyName': 'VTSS Ha',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/VTSSHa/',
#   'surveyFrame': 'GALACTIC',
#   'maximumNorder': 3,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'cds.png',
#   'colorPalette': 'NATIVE'},
#  'Mellinger color': {'mission': 'Mellinger optical survey',
#   'missionURL': 'http://www.milkywaysky.com/',
#   'wavelengthRange': '370 - 700 nm',
#   'instrument': 'SBIG STL-11000 camera',
#   'creator': 'Centre de Donnees astronomiques de Strasbourg',
#   'creatorURL': 'http://cdsweb.u-strasbg.fr',
#   'creationDate': '2010-07-12T00:00Z',
#   'moreInfoURL': 'http://alasky.u-strasbg.fr/MellingerRGB/properties',
#   'surveyId': 'Mellinger color',
#   'surveyName': 'Mellinger color',
#   'surveyRootUrl': 'http://alasky.u-strasbg.fr/MellingerRGB/',
#   'surveyFrame': 'GALACTIC',
#   'maximumNorder': 4,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'cds.png',
#   'colorPalette': 'NATIVE'},
#  'Finkbeiner Ha': {'mission': 'Finkbeiner Halpha composite survey',
#   'missionURL': 'http://lambda.gsfc.nasa.gov/product/foreground/halpha_map.cfm',
#   'wavelengthRange': '6563 &Aring;',
#   'instrument': 'VT SLIC, WHAM, CCD @1m telescope on CTIO',
#   'creator': 'Centre de Donnees astronomiques de Strasbourg',
#   'creatorURL': 'http://cdsweb.u-strasbg.fr',
#   'creationDate': '2010-12-14T01:07Z',
#   'moreInfoURL': 'http://alasky.u-strasbg.fr/FinkbeinerHalpha/properties',
#   'surveyId': 'Finkbeiner Ha',
#   'surveyName': 'Finkbeiner Ha',
#   'surveyRootUrl': 'http://cdn.skies.esac.esa.int/FinkbeinerHa/',
#   'surveyFrame': 'GALACTIC',
#   'maximumNorder': 3,
#   'imgFormat': 'jpg',
#   'isDefault': False,
#   'icon': 'cds.png',
#   'colorPalette': 'NATIVE'}}
